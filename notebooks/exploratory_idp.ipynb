# %% [markdown]
# # Exploratory IDP Analysis
#
# Experiments with OCR/extraction from various document types.

# %%
import sys
sys.path.append('..')

from app.services.idp_pipeline import parse_document
from pathlib import Path

# %%
# Example: Parse a sample document
sample_doc = "../data/raw_docs/sample.pdf"
if Path(sample_doc).exists():
    result = parse_document(sample_doc, "invoice")
    print(result)
